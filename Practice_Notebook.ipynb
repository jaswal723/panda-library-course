# %%
import pandas as pd

# %%
pd.DataFrame({"Name":["Rithik","Mukul","Kunal"],"Age":[25,25,26],"Place":["Hamirpur","Shimla","Delhi"]})
# Out:
#      Name  Age     Place
# 0  Rithik   25  Hamirpur
# 1   Mukul   25    Shimla
# 2   Kunal   26     Delhi

# %%
pd.DataFrame({"Name":["Rithik","Mukul","Kunal"],"Age":[25,25,26],"Place":["Hamirpur","Shimla","Delhi"]},index=["User1","User2","User3"])
# Out:
#          Name  Age     Place
# User1  Rithik   25  Hamirpur
# User2   Mukul   25    Shimla
# User3   Kunal   26     Delhi

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
userlist = pd.DataFrame({"Name":["Rithik","Mukul","Kunal"],"Age":[25,25,26],"Place":["Hamirpur","Shimla","Delhi"]},index=["User1","User2","User3"])

# %%
userlist
# Out:
#          Name  Age     Place
# User1  Rithik   25  Hamirpur
# User2   Mukul   25    Shimla
# User3   Kunal   26     Delhi

# %%
userlist.Name
# Out:
# User1    Rithik
# User2     Mukul
# User3     Kunal
# Name: Name, dtype: object

# %%
userlist.to_csv("list_of_users.csv")

# %%
reading_csv = pd.read_csv("list_of_users.csv",index_col=0)

# %%
reading_csv
# Out:
#          Name  Age     Place
# User1  Rithik   25  Hamirpur
# User2   Mukul   25    Shimla
# User3   Kunal   26     Delhi

# %%
reading_csv.shape
# Out:
# (3, 3)

# %%
reading_csv.head()
# Out:
#          Name  Age     Place
# User1  Rithik   25  Hamirpur
# User2   Mukul   25    Shimla
# User3   Kunal   26     Delhi

# %%
reading_csv.Age
# Out:
# User1    25
# User2    25
# User3    26
# Name: Age, dtype: int64

# %%
reading_csv.Place
# Out:
# User1    Hamirpur
# User2      Shimla
# User3       Delhi
# Name: Place, dtype: object

# %%
reading_csv["Place"]
# Out:
# User1    Hamirpur
# User2      Shimla
# User3       Delhi
# Name: Place, dtype: object

# %%
reading_csv["Place"][2]
# Out:
# C:\Users\jaswa\AppData\Local\Temp\ipykernel_41520\4217210329.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   reading_csv["Place"][2]
# 'Delhi'

# %%
reading_csv.iloc[0]
# Out:
# Name       Rithik
# Age            25
# Place    Hamirpur
# Name: User1, dtype: object

# %%
reading_csv.iloc[0,2]
# Out:
# 'Hamirpur'

# %%
reading_csv.iloc[:,2]
# Out:
# User1    Hamirpur
# User2      Shimla
# User3       Delhi
# Name: Place, dtype: object

# %%
reading_csv.iloc[1:2,2]
# Out:
# User2    Shimla
# Name: Place, dtype: object

# %%
reading_csv.iloc[-1]
# Out:
# Name     Kunal
# Age         26
# Place    Delhi
# Name: User3, dtype: object

# %%
reading_csv.loc["User2"]
# Out:
# Name      Mukul
# Age          25
# Place    Shimla
# Name: User2, dtype: object

# %%
reading_csv.loc[:,"Place"]
# Out:
# User1    Hamirpur
# User2      Shimla
# User3       Delhi
# Name: Place, dtype: object

# %%
reading_csv.loc["User1","Place"]
# Out:
# 'Hamirpur'

# %%
reading_csv.loc["User1",["Age","Place"]]
# Out:
# Age            25
# Place    Hamirpur
# Name: User1, dtype: object

# %%
reading_csv.Age == 25
# Out:
# User1     True
# User2     True
# User3    False
# Name: Age, dtype: bool

# %%
reading_csv.loc[reading_csv.Age == 25]
# Out:
#          Name  Age     Place
# User1  Rithik   25  Hamirpur
# User2   Mukul   25    Shimla

# %%
reading_csv.loc[(reading_csv.Age == 25) | (reading_csv.Name == "Kunal") ]
# Out:
#          Name  Age     Place
# User1  Rithik   25  Hamirpur
# User2   Mukul   25    Shimla
# User3   Kunal   26     Delhi

# %%
reading_csv.loc[(reading_csv.Age == 25) & (reading_csv.Name == "Rithik") ]
# Out:
#          Name  Age     Place
# User1  Rithik   25  Hamirpur

# %%
reading_csv.loc[reading_csv.Place.isin(["Hamirpur","Shimla"])]
# Out:
#          Name  Age     Place
# User1  Rithik   25  Hamirpur
# User2   Mukul   25    Shimla

# %%
reading_csv["county"] = "India"

# %%
reading_csv
# Out:
#          Name  Age     Place county
# User1  Rithik   25  Hamirpur  India
# User2   Mukul   25    Shimla  India
# User3   Kunal   26     Delhi  India

# %%
reading_csv["Serial Number"] = range(1,4)

# %%
reading_csv
# Out:
#          Name  Age     Place county  Serial Number
# User1  Rithik   25  Hamirpur  India              1
# User2   Mukul   25    Shimla  India              2
# User3   Kunal   26     Delhi  India              3

# %%
reading_csv.set_index("Serial Number")
# Out:
#                  Name  Age     Place county
# Serial Number
# 1              Rithik   25  Hamirpur  India
# 2               Mukul   25    Shimla  India
# 3               Kunal   26     Delhi  India

# %%
reading_csv.describe()
# Out:
#              Age  Serial Number
# count   3.000000            3.0
# mean   25.333333            2.0
# std     0.577350            1.0
# min    25.000000            1.0
# 25%    25.000000            1.5
# 50%    25.000000            2.0
# 75%    25.500000            2.5
# max    26.000000            3.0

# %%
reading_csv.Place.describe()
# Out:
# count            3
# unique           3
# top       Hamirpur
# freq             1
# Name: Place, dtype: object

# %%
reading_csv.Age.median()
# Out:
# 25.0

# %%
reading_csv.Place.unique()
# Out:
# array(['Hamirpur', 'Shimla', 'Delhi'], dtype=object)

# %%
reading_csv.Place.value_counts()
# Out:
# Place
# Hamirpur    1
# Shimla      1
# Delhi       1
# Name: count, dtype: int64

# %%
current_year = 2025
reading_csv["BirthYear"] = 1

# %%
reading_csv
# Out:
#          Name  Age     Place county  Serial Number  BirthYear
# User1  Rithik   25  Hamirpur  India              1          1
# User2   Mukul   25    Shimla  India              2          1
# User3   Kunal   26     Delhi  India              3          1

# %%
reading_csv["BirthYear"].map(lambda p: current_year - reading_csv.Age)
# Out:
# User1    User1    2000
# User2    2000
# User3    1999
# Name...
# User2    User1    2000
# User2    2000
# User3    1999
# Name...
# User3    User1    2000
# User2    2000
# User3    1999
# Name...
# Name: BirthYear, dtype: object

# %%
reading_csv
# Out:
#          Name  Age     Place county  Serial Number  BirthYear
# User1  Rithik   25  Hamirpur  India              1          1
# User2   Mukul   25    Shimla  India              2          1
# User3   Kunal   26     Delhi  India              3          1

# %%
birth_year = reading_csv["BirthYear"].map(lambda p: current_year - reading_csv.Age)

# %%
birth_year
# Out:
# User1    User1    2000
# User2    2000
# User3    1999
# Name...
# User2    User1    2000
# User2    2000
# User3    1999
# Name...
# User3    User1    2000
# User2    2000
# User3    1999
# Name...
# Name: BirthYear, dtype: object

# %%
reading_csv["BirthYear"] = birth_year

# %%
reading_csv
# Out:
#          Name  Age     Place county  Serial Number  \
# User1  Rithik   25  Hamirpur  India              1
# User2   Mukul   25    Shimla  India              2
# User3   Kunal   26     Delhi  India              3
#
#                                                BirthYear
# User1  User1    2000
# User2    2000
# User3    1999
# Name...
# User2  User1    2000
# User2    2000
# User3    1999
# Name...
# User3  User1    2000
# User2    2000
# User3    1999
# Name...

# %%
reading_csv["BirthYear"] = reading_csv["BirthYear"].map(lambda p: current_year - reading_csv.Age)

# %%
reading_csv
# Out:
#          Name  Age     Place county  Serial Number  \
# User1  Rithik   25  Hamirpur  India              1
# User2   Mukul   25    Shimla  India              2
# User3   Kunal   26     Delhi  India              3
#
#                                                BirthYear
# User1  User1    2000
# User2    2000
# User3    1999
# Name...
# User2  User1    2000
# User2    2000
# User3    1999
# Name...
# User3  User1    2000
# User2    2000
# User3    1999
# Name...

# %%
reading_csv.Age.map(lambda p: 2025 - p)
# Out:
# User1    2000
# User2    2000
# User3    1999
# Name: Age, dtype: int64

# %%
reading_csv
# Out:
#          Name  Age     Place county  Serial Number  \
# User1  Rithik   25  Hamirpur  India              1
# User2   Mukul   25    Shimla  India              2
# User3   Kunal   26     Delhi  India              3
#
#                                                BirthYear
# User1  User1    2000
# User2    2000
# User3    1999
# Name...
# User2  User1    2000
# User2    2000
# User3    1999
# Name...
# User3  User1    2000
# User2    2000
# User3    1999
# Name...

# %%
reading_csv["BirthYear"] = 0

# %%
reading_csv
# Out:
#          Name  Age     Place county  Serial Number  BirthYear
# User1  Rithik   25  Hamirpur  India              1          0
# User2   Mukul   25    Shimla  India              2          0
# User3   Kunal   26     Delhi  India              3          0

# %%
reading_csv["BirthYear"] = reading_csv["BirthYear"].map(lambda p: 2025 - p)

# %%
reading_csv
# Out:
#          Name  Age     Place county  Serial Number  BirthYear
# User1  Rithik   25  Hamirpur  India              1       2025
# User2   Mukul   25    Shimla  India              2       2025
# User3   Kunal   26     Delhi  India              3       2025

# %%
reading_csv["BirthYear"] = reading_csv.Age

# %%
reading_csv
# Out:
#          Name  Age     Place county  Serial Number  BirthYear
# User1  Rithik   25  Hamirpur  India              1         25
# User2   Mukul   25    Shimla  India              2         25
# User3   Kunal   26     Delhi  India              3         26

# %%
reading_csv["BirthYear"] = reading_csv["BirthYear"].map(lambda p: 2025 - p)

# %%
reading_csv
# Out:
#          Name  Age     Place county  Serial Number  BirthYear
# User1  Rithik   25  Hamirpur  India              1       2000
# User2   Mukul   25    Shimla  India              2       2000
# User3   Kunal   26     Delhi  India              3       1999

# %%
def row_function(row):
    if row.Place == "Hamirpur" or row.Place == "Shimla":
        return "Himachal Pradesh"
    else:
        return "NCT"

# %%
reading_csv["State"] = ""

# %%
reading_csv
# Out:
#          Name  Age     Place county  Serial Number  BirthYear State
# User1  Rithik   25  Hamirpur  India              1       2000
# User2   Mukul   25    Shimla  India              2       2000
# User3   Kunal   26     Delhi  India              3       1999

# %%
reading_csv["State"] = reading_csv.apply(row_function,axis="columns")

# %%
print("Hello")
# Out:
# Hello

# %%
reading_csv
# Out:
#          Name  Age     Place county  Serial Number  BirthYear  \
# User1  Rithik   25  Hamirpur  India              1       2000
# User2   Mukul   25    Shimla  India              2       2000
# User3   Kunal   26     Delhi  India              3       1999
#
#                   State
# User1  Himachal Pradesh
# User2  Himachal Pradesh
# User3               NCT

# %%
reading_csv.Age.value_counts()
# Out:
# Age
# 25    2
# 26    1
# Name: count, dtype: int64

# %%
reading_csv.groupby("Age")

# %%
reading_csv
# Out:
#          Name  Age     Place county  Serial Number  BirthYear  \
# User1  Rithik   25  Hamirpur  India              1       2000
# User2   Mukul   25    Shimla  India              2       2000
# User3   Kunal   26     Delhi  India              3       1999
#
#                   State
# User1  Himachal Pradesh
# User2  Himachal Pradesh
# User3               NCT

# %%
groupedvalue = reading_csv.groupby("Age")

# %%
groupedvalue

# %%
print(groupedvalue)

# %%
reading_csv.groupby("Age").Age.count()
# Out:
# Age
# 25    2
# 26    1
# Name: Age, dtype: int64

# %%
reading_csv.groupby("Age").BirthYear.min()
# Out:
# Age
# 25    2000
# 26    1999
# Name: BirthYear, dtype: int64
